# %% [markdown]
# # HW : Missing data imputation with gibbs sampling
# ### 교재 7.5 장
# ### 과제의 흐름?
# * 이번 과제에서는 먼저 diabetes dataset에서 glucose, bloodpressure, skinthickness, BMI 4개의 columns에서 missing data(NA)를 찾고 original data의 분포를 먼저 그려봅니다.
# * 그 후 첫번째로 sample mean을 이용하여 NA를 처리하는 방법을 볼텐데, 그 결과의 분포가 original 분포와 차이가 있어 좋지 못한 방법이라는 것을 알 수 있을 것 입니다.
# * 마지막으로 gibbs sampling을 이용해 NA를 처리하는데, 그 결과의 분포가 original 분포와 유사하다는 것을 확인하며 이전의 방법보다 좋다라는 것을 알 수 있을 것입니다.

# %% [markdown]
# ### CONTENTS
# #### 1. Importing
# #### 2. Data Load
# #### 3. Make NA
# #### 4. Check NA
# #### 5. Setting Priors
# #### 6. Method 1 : Filling with sample mean
# #### * 7. Method 2 : Filling with Gibbs sampling

# %% [markdown]
# ## 1. Importing

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\chaeh\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy in c:\users\chaeh\anaconda3\lib\site-packages (from missingno) (1.7.1)
# Requirement already satisfied: numpy in c:\users\chaeh\anaconda3\lib\site-packages (from missingno) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\chaeh\anaconda3\lib\site-packages (from missingno) (3.4.3)
# Requirement already satisfied: seaborn in c:\users\chaeh\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chaeh\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\chaeh\anaconda3\lib\site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chaeh\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chaeh\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chaeh\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: six in c:\users\chaeh\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\chaeh\anaconda3\lib\site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\chaeh\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import wishart

import missingno as msno #결측데이터를 파악하는데 도움을 주는 패키지 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Load

# %%
diabetes = pd.read_csv('C:/Users/chaeh/OneDrive/session code/week4/diabetes.csv')
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# only need 4 columns
data = diabetes[['Glucose', 'BloodPressure', 'SkinThickness', 'BMI']]  #당뇨병 데이터에서 네가지 변수만 선택하기
data.isna().sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# BMI              0
# dtype: int64

# %% [markdown]
# 데이터에 있는 glucose, bloodpressure, skinthickness, BMI 가 0일리는 없음
# missing data를 0값으로 둔거라 0을 NA로 바꾼다.

# %% [markdown]
# ## 3. Make NA

# %%
# Change zero values to NaN (null)
data = data.replace(0, np.nan)
print(data.isnull().sum())  #각각 실제 결측치는 다음과 같은 결과이다
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# BMI               11
# dtype: int64

# %% [markdown]
# ## 4. Check NA

# %%
# Visualize the number of missing values as a matrix
# 결측치 시각화하기
fig = msno.matrix(data, figsize=(13.33,7.5))

# Add labels
plt.xlabel('Variables', size=24, labelpad=16)
plt.ylabel('Total Observations', size=24, labelpad=16)
plt.tick_params(axis='both', labelsize=16, length=8)

plt.show()

# %% [markdown]
# missing data가 생성된걸 확인 할 수 있다.\
# 결측치는 SkinThickness가 가장 많다.

# %%
# Visualize the number of missing values as a heatmap
# 결측치 간의 상관관계 알아보기
fig = msno.heatmap(data, figsize=(12,8))

# Add labels
plt.xlabel('Variables with Missing Values', size=20, labelpad=24)
plt.ylabel('Variables with Missing Values', size=20, labelpad=24)
plt.tick_params(axis='both', labelsize=12, length=6)

plt.show();

# %% [markdown]
# bloodpressure와 skinthickness의 상관관계가 높은 것을 확인할 수 있다.

# %%
g = sns.pairplot(data, diag_kind="kde") #kde는 변수별 커널밀도추정곡선 (히스토그램과 유사)
g.map_lower(sns.kdeplot, levels=4, color=".2") #대각선 아래 부분 kdeplot으로 겹치기.

# %% [markdown]
# skinthickness와 이후의 결과를 비교하면서 알아보기

# %% [markdown]
# ## 5. Setting Priors

# %%
n = data.shape[0]       # data 수    x.shape = (행, 열) -> 튜플
p = data.shape[1]       # column 수

S = 100                 # number of iteration

# 자주 쓰는 함수
inv = np.linalg.inv     # inverse matrix
t = np.transpose        # transpose
mul = np.matmul         # matrix multiplication

# %%
# priors (initializing params of prior dist) 설정

## 1. prior for mu ~ N(mu0,L0)
# 1.1 mean vector mu0
mu0 = data.mean().to_numpy()    # column mean  /  변수별 평균 구해서 pandas객체를 numpy로 바꾸기

# 1.2 covariance matrix Lambda0 : 공분산 행렬 만들기
# 정확한 이유는 모르지만 나름의 믿음으로 prior params intializing
sd0 = mu0 / 2                   

L0 = np.ones((p,p))*0.1         # Lambda0 in prior  /  p=열의 수, p행 p열의 원소가 1인 행렬을 만들고 0.1을 곱한다.

di = np.diag_indices(p)         # diagonal index  /  대각선 원소에 접근할 것이다. p는 대각선 원소 개수..? 
L0[di] = 1                      # all variance = 1   /   대각선 원소를 1로 바꾼다.

L0 = L0 * np.outer(sd0, sd0)    # off-diagonal elements  /  np.outer( , ): 두 벡터에 대한 외부 곱

## 2. prior for Sigma ~ Ing-Wishart(nu0,S0)
nu0 = p + 2                     
S0 = L0

# %% [markdown]
# mu_0: 각 데이터의 평균 \
# lamda_0: ...? 책에 별다른 설명 없음. \
# prior for sigma: sigma를 중심으로 느슨하게 퍼져있게 한다. -> nu_0, S0 다음과 같이 설정(p117에 설명), inv-Wishart를 따른다.

# %% [markdown]
# ## 6. Method 1 : Filling with sample mean

# %%
# setting
Sigma = S0                      # mu의 full conditional posterior를 초기화하는데 필요
fill_data = data.copy()         # imputate할 dataset copy

# O_(i,j)
O = data.isna().to_numpy()*1    # indicator variable (missing = 1, observed = 0) / na를 T/F -> 배열로 변형 -> 1 or 0값으로 T/F 변환

# Naive Imputation(Using sample mean)
for col in fill_data.columns:
    fill_data[col].fillna(fill_data[col].mean(), inplace=True) #각 변수별 결측값을 변수의 평균으로 채우기

# %%
g_naive = sns.pairplot(fill_data, diag_kind="kde")
g_naive.map_lower(sns.kdeplot, levels=4, color=".2")

# %% [markdown]
# #### 위 4.에서 구한 데이터의 분포와 비교했을 때 SkinThickness의 분포 모양이 눈에 띄게 차이남.
# #### sample mean으로 impute 하는데 문제가 있다는 뜻.

# %% [markdown]
# ## * 7. Method 2 : Filling with Gibbs sampling

# %%
# inv, mul 쓰세요!
inv = np.linalg.inv
mul = np.matmul

for s in range(S):
    # update mu
    ybar = fill_data.mean().to_numpy()
    ######################## TO DO #############################
    # Mu를 sampling 하기 위해서는 아래의 'multivariate_normal.rvs(mun, Ln)'에 들어가는
    # mun 과 Ln을 매번 update해줘야 하기때문에 아래에서 @를 알맞은 값 또는 식으로 바꾸어보아요.
    # hint1 : 교재 equation (7.4) (7.5) 참고
    # hint2 : inv, mul을 사용하고 prior parameter(L0, Sigma, mu0)를 잘 사용해 보세요.
    Ln = inv(inv(L0) + n*inv(Sigma))  #7.4
    mun = mul(Ln, np.dot(inv(L0), mu0) + n*mul(inv(Sigma),ybar))   #7.5
    ############################################################
    Mu = stats.multivariate_normal.rvs(mun, Ln)      #7.6

    # update Sigma
    Sn = S0 + mul(t(fill_data-Mu).to_numpy(), (fill_data-Mu).to_numpy())  #118쪽 7.8 밑의 수식
    ######################## TO DO #############################
    # 아래의 inv(wishart.rvs(@, inv(Sn)) 에서 @안을 채우세요!
    # hint : Sigma의 prior parameter인 nu0을 사용합니다.
    Sigma = inv(wishart.rvs(nu0+n, inv(Sn)))    #(7.9)
    ############################################################
    
    # update missing data
    for i in range(n):

        # row별로 돌아가면서 1x4 array에 대해서 imputation
        # [T, F, F, T] 등의 형태로 indexing
        a = O[i,]==0        # i번째 row에 결측치 없는 위치
        b = O[i,]==1        # i번째 row에 결측치 있는 위치

        if sum(b)!=0:       # 결측치가 하나라도 있으면(if sum(b)!=0, imputation!) (if sum(b)==0, no imputation)
            # FCB p118 (7.10), (7.11) equation 설명 참고
            iSa = inv(Sigma[np.outer(a,a)].reshape(sum(a),sum(a)))
            beta_j = mul(Sigma[np.outer(b,a)].reshape(sum(b),sum(a)), iSa)

            # Covariance Matrix for MVN distribution
            Sigma_j = Sigma[np.outer(b,b)].reshape(sum(b),sum(b)) - np.linalg.multi_dot([Sigma[np.outer(b,a)].reshape(sum(b),sum(a)), 
                                                                                         iSa, Sigma[np.outer(a,b)].reshape(sum(a),sum(b))])
            # Mean Vector for MVN distribution
            mu_j = Mu[b] + mul(beta_j, t(fill_data.iloc[i, a])-Mu[a])

            # MVN 에서 결측치 있는 위치 (b)만 sampling한 값으로 채우기!
            fill_data.iloc[i,b] = stats.multivariate_normal.rvs(mu_j, Sigma_j, 1)

    if s%10==0:
        print(s,"/",S)
# Out:
# 0 / 100
# 10 / 100
# 20 / 100
# 30 / 100
# 40 / 100
# 50 / 100
# 60 / 100
# 70 / 100
# 80 / 100
# 90 / 100

# %%
# Visualize the number of missing values as a matrix
fig = msno.matrix(fill_data, figsize=(13.33,7.5))

# Add labels
plt.xlabel('Variables', size=24, labelpad=16)
plt.ylabel('Total Observations', size=24, labelpad=16)
plt.tick_params(axis='both', labelsize=16, length=8)

plt.show()

# %% [markdown]
# 결측치 모두 제거함

# %%
g_filled = sns.pairplot(fill_data, diag_kind="kde")
g_filled.map_lower(sns.kdeplot, levels=4, color=".2")

# %% [markdown]
# #### 첫 분포와 비교해보면 skinthickness의 분포도 나머지 3개 처럼 첫 분포와 비슷한 양상을 띔
# #### 평균값 대체보다는 Gibbs sampling 방법이 더 좋은 대체 방법!!
